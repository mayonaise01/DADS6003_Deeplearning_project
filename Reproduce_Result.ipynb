ontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.4500, 0.7200)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, gmf_ndcg_8, label='GMF')
plt.plot(epochs, mlp_ndcg_8, label='MLP')
plt.plot(epochs, neumf_ndcg_8, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG Comparison [Factor 8]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.260, 0.450)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, gmf_loss_8, label='GMF')
plt.plot(epochs, mlp_loss_8, label='MLP')
plt.plot(epochs, neumf_loss_8, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Comparison [Factor 8]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.160, 0.370)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

plt.tight_layout()
plt.show()

# %%
# factor 16 result

epochs = list(range(50))

# GMF Data for Factor 16
gmf_hr_16 = [0.5397, 0.6003, 0.6276, 0.6425, 0.6608, 0.6629, 0.6682, 0.6700, 0.6732, 0.6757, 0.6796, 0.6815, 0.6834, 0.6793, 0.6810, 0.6841, 0.6833, 0.6868, 0.6894, 0.6904, 0.6897, 0.6891, 0.6897, 0.6904, 0.6909, 0.6904, 0.6919, 0.6902, 0.6874, 0.6879, 0.6914, 0.6864, 0.6884, 0.6891, 0.6868, 0.6892, 0.6892, 0.6886, 0.6899, 0.6891, 0.6911, 0.6877, 0.6914, 0.6884, 0.6916, 0.6914, 0.6962, 0.6904, 0.6914, 0.6902]
gmf_ndcg_16 = [ 0.3021, 0.3412, 0.3626, 0.3720, 0.3848, 0.3894, 0.3911, 0.3927, 0.3975, 0.3967, 0.3998, 0.4049, 0.4035, 0.4026, 0.4058, 0.4074, 0.4070, 0.4081, 0.4088, 0.4107, 0.4092, 0.4096, 0.4095, 0.4091, 0.4098, 0.4111, 0.4128, 0.4115, 0.4106, 0.4091, 0.4105, 0.4087, 0.4096, 0.4108, 0.4092, 0.4096, 0.4093, 0.4100, 0.4099, 0.4110, 0.4115, 0.4103, 0.4130, 0.4110, 0.4115, 0.4123, 0.4125, 0.4118, 0.4103, 0.4117]
gmf_loss_16 = [0.3486, 0.2929, 0.2733, 0.2642, 0.2578, 0.2534, 0.2510, 0.2491, 0.2476, 0.2466, 0.2456, 0.2450, 0.2441, 0.2437, 0.2431, 0.2427, 0.2422, 0.2421, 0.2417, 0.2412, 0.2412, 0.2408, 0.2406, 0.2406, 0.2407, 0.2404, 0.2403, 0.2399, 0.2398, 0.2398, 0.2394, 0.2392, 0.2396, 0.2392, 0.2392, 0.2391, 0.2391, 0.2392, 0.2389, 0.2387, 0.2387, 0.2388, 0.2389, 0.2385, 0.2384, 0.2387, 0.2383, 0.2384, 0.2386, 0.2384]

# MLP Data for Factor 16
mlp_hr_16 = [ 0.5285, 0.5836, 0.6247, 0.6387, 0.6379, 0.6533, 0.6586, 0.6639, 0.6690, 0.6730, 0.6727, 0.6679, 0.6785, 0.6763, 0.6705, 0.6780, 0.6776, 0.6820, 0.6775, 0.6826, 0.6783, 0.6811, 0.6786, 0.6833, 0.6783, 0.6773, 0.6783, 0.6801, 0.6805, 0.6815, 0.6805, 0.6828, 0.6844, 0.6828, 0.6823, 0.6801, 0.6836, 0.6798, 0.6853, 0.6805, 0.6844, 0.6823, 0.6783, 0.6760, 0.6829, 0.6836, 0.6843, 0.6831, 0.6795, 0.6816]
    0.3192, 0.2741, 0.2640, 0.2583, 0.2543, 0.2511, 0.2485, 0.2464, 0.2449, 0.2437,0.2419, 0.2407, 0.2396, 0.2386, 0.2376, 0.2369, 0.2362, 0.2357, 0.2350, 0.2343, 0.2339, 0.2336, 0.2332, 0.2329, 0.2325, 0.2326, 0.2315, 0.2312, 0.2314, 0.2309,0.2309, 0.2306, 0.2305, 0.2300, 0.2299, 0.2297, 0.2295, 0.2293, 0.2290, 0.2292,0.2288, 0.2287, 0.2287, 0.2281, 0.2282, 0.2280, 0.2279, 0.2280, 0.2276, 0.2276]

# Plotting the graphs with NeuMF included
plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(epochs, gmf_hr_16, label='GMF')
plt.plot(epochs, mlp_hr_16, label='MLP')
plt.plot(epochs, neumf_hr_16, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('HR', fontsize=14)
plt.title('HR Comparison [Factor 16]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.4500, 0.7200)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, gmf_ndcg_16, label='GMF')
plt.plot(epochs, mlp_ndcg_16, label='MLP')
plt.plot(epochs, neumf_ndcg_16, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG Comparison [Factor 16]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.260, 0.450)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, gmf_loss_16, label='GMF')
plt.plot(epochs, mlp_loss_16, label='MLP')
plt.plot(epochs, neumf_loss_16, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Comparison [Factor 16]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.160, 0.370)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))


plt.tight_layout()
plt.show()

# %%
# factor 32 result
epochs = list(range(50))
# GMF Data for Factor 32
gmf_hr_32 = [ 0.5801, 0.6288, 0.6546, 0.6750, 0.6795, 0.6950, 0.6977, 0.6997, 0.6980, 0.6995, 0.7022, 0.7007, 0.7010, 0.7043, 0.7061, 0.7050, 0.7028, 0.7061, 0.7036, 0.7066, 0.7065, 0.7046, 0.7030, 0.7096, 0.7089, 0.7066, 0.7081, 0.7084, 0.7036, 0.7041, 0.7088, 0.7083, 0.7083, 0.7089, 0.7094, 0.7129, 0.7066, 0.7114, 0.7061, 0.7084, 0.7104, 0.7088, 0.7056, 0.7065, 0.7066, 0.7081, 0.7124, 0.7098, 0.7098, 0.7075]
gmf_ndcg_32 = [ 0.3281, 0.3620, 0.3822, 0.3969, 0.4021, 0.4109, 0.4147, 0.4168, 0.4192, 0.4185, 0.4211, 0.4215, 0.4209, 0.4262, 0.4240, 0.4258, 0.4268, 0.4262, 0.4286, 0.4285, 0.4277, 0.4265, 0.4278, 0.4281, 0.4310, 0.4288, 0.4292, 0.4271, 0.4272, 0.4289, 0.4304, 0.4302, 0.4302, 0.4303, 0.4300, 0.4323, 0.4288, 0.4317, 0.4295, 0.4310, 0.4308, 0.4314, 0.4295, 0.4287, 0.4309, 0.4299, 0.4322, 0.4309, 0.4303, 0.4293]
gmf_loss_32 = [0.3343, 0.2808, 0.2622, 0.2517, 0.2442, 0.2384, 0.2337, 0.2302, 0.2275, 0.2254, 0.2239, 0.2224, 0.2212, 0.2203, 0.2195, 0.2188, 0.2181, 0.2172, 0.2170, 0.2165, 0.2160, 0.2156, 0.2154, 0.2150, 0.2147, 0.2143, 0.2144, 0.2138, 0.2135, 0.2133, 0.2130, 0.2127, 0.2126, 0.2126, 0.2124, 0.2123, 0.2122, 0.2120, 0.2121, 0.2118, 0.2116, 0.2117, 0.2111, 0.2111, 0.2112, 0.2109, 0.2110, 0.2108, 0.2109, 0.2110]

neumf_ndcg_32 = [ 0.3372, 0.3661, 0.3755, 0.3841, 0.3903, 0.3964, 0.3968, 0.3968, 0.4013, 0.4033, 0.4047, 0.4068, 0.4050, 0.4068, 0.4083, 0.4065, 0.4102, 0.4106, 0.4094, 0.4079, 0.4106, 0.4113, 0.4120, 0.4107, 0.4104, 0.4116, 0.4111, 0.4084, 0.4115, 0.4095, 0.4116, 0.4117, 0.4098, 0.4103, 0.4101, 0.4120, 0.4076, 0.4087, 0.4113, 0.4115, 0.4097, 0.4100, 0.4121, 0.4115, 0.4086, 0.4082, 0.4079, 0.4064, 0.4100,0.4107]
neumf_loss_32 = [0.3193, 0.2752, 0.2646, 0.2594, 0.2557, 0.2523, 0.2496, 0.2472, 0.2453, 0.2434, 0.2419, 0.2408, 0.2397, 0.2388, 0.2380, 0.2370, 0.2365, 0.2359, 0.2353, 0.2348, 0.2342, 0.2339, 0.2331, 0.2329, 0.2325, 0.2322, 0.2318, 0.2317, 0.2313, 0.2310, 0.2307, 0.2307, 0.2304, 0.2299, 0.2297, 0.2295, 0.2295, 0.2292, 0.2289, 0.2290, 0.2288, 0.2287, 0.2286, 0.2283, 0.2279, 0.2279, 0.2279, 0.2279, 0.2275, 0.2276]


# Plotting the graphs with NeuMF included
plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(epochs, gmf_hr_32, label='GMF')
plt.plot(epochs, mlp_hr_32, label='MLP')
plt.plot(epochs, neumf_hr_32, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('HR', fontsize=14)
plt.title('HR Comparison [Factor 32]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.4500, 0.7200)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, gmf_ndcg_32, label='GMF')
plt.plot(epochs, mlp_ndcg_32, label='MLP')
plt.plot(epochs, neumf_ndcg_32, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG Comparison [Factor 32]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.260, 0.450)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, gmf_loss_32, label='GMF')
plt.plot(epochs, mlp_loss_32, label='MLP')
plt.plot(epochs, neumf_loss_32, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Comparison [Factor 32]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.160, 0.370)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))


plt.tight_layout()
plt.show()

# %%
# factor 64 result
epochs = list(range(50))
# Data for GMF
gmf_hr_64 = [0.6066, 0.6477, 0.6709, 0.6866, 0.6934, 0.6997, 0.6947, 0.6925, 0.6924, 0.6907, 0.6924, 0.6876, 0.6907, 0.6904, 0.6884, 0.6907, 0.6969, 0.6954, 0.6937, 0.6917, 0.6930, 0.6934, 0.6934, 0.6925, 0.6945, 0.6934, 0.6939, 0.6921, 0.6922, 0.6942, 0.6904, 0.6944, 0.6921, 0.6930, 0.6927, 0.6947, 0.6947, 0.6925, 0.6911, 0.6882, 0.6927, 0.6945, 0.6919, 0.6904, 0.6919, 0.6909, 0.6925, 0.6881, 0.6891,0.6894]
gmf_ndcg_64= [ 0.3424, 0.3761, 0.3939, 0.4069, 0.4142, 0.4189, 0.4208, 0.4210, 0.4224, 0.4215, 0.4253, 0.4216, 0.4235, 0.4241, 0.4241, 0.4235, 0.4246, 0.4236, 0.4245, 0.4226, 0.4222, 0.4231, 0.4248, 0.4236, 0.4217, 0.4232, 0.4229, 0.4223, 0.4224, 0.4207, 0.4184, 0.4216, 0.4193, 0.4211, 0.4232, 0.4206, 0.4227, 0.4213, 0.4202, 0.4172, 0.4197, 0.4197, 0.4182, 0.4204, 0.4197, 0.4192, 0.4189, 0.4183, 0.4165,0.4187]
neumf_hr_64 = [ 0.6445, 0.6805, 0.6833, 0.6874, 0.6886, 0.6894, 0.6881, 0.6851, 0.6858, 0.6846, 0.6826, 0.6808, 0.6831, 0.6853, 0.6892, 0.6851, 0.6863, 0.6882, 0.6899, 0.6801, 0.6844, 0.6806, 0.6770, 0.6844, 0.6820, 0.6821, 0.6821, 0.6815, 0.6846, 0.6831, 0.6791, 0.6834, 0.6783, 0.6834, 0.6815, 0.6843, 0.6770, 0.6829, 0.6760, 0.6775, 0.6775, 0.6776, 0.6828, 0.6762, 0.6795, 0.6806, 0.6765, 0.6763, 0.6815,0.6820]
neumf_ndcg_64 = [0.3717, 0.4048, 0.4134, 0.4161, 0.4168, 0.4148, 0.4165, 0.4168, 0.4179, 0.4190, 0.4175, 0.4124, 0.4176, 0.4213, 0.4207, 0.4166, 0.4160, 0.4169, 0.4171, 0.4116, 0.4159, 0.4127, 0.4118, 0.4137, 0.4139, 0.4155, 0.4152, 0.4132, 0.4147, 0.4140, 0.4131, 0.4133, 0.4119, 0.4143, 0.4129, 0.4131, 0.4089, 0.4129, 0.4121, 0.4120, 0.4115, 0.4112, 0.4110, 0.4092, 0.4129, 0.4117, 0.4118, 0.4097, 0.4121,0.4124]
neumf_loss_64 = [0.3025, 0.2474, 0.2268, 0.2159, 0.2085, 0.2032, 0.1991, 0.1960, 0.1933, 0.1912, 0.1892, 0.1873, 0.1858, 0.1842, 0.1829, 0.1817, 0.1805, 0.1796, 0.1786, 0.1780, 0.1770, 0.1764, 0.1755, 0.1753, 0.1744, 0.1740, 0.1731, 0.1725, 0.1722, 0.1716, 0.1711, 0.1708, 0.1704, 0.1702, 0.1695, 0.1691, 0.1689, 0.1684, 0.1682, 0.1678, 0.1673, 0.1674, 0.1670, 0.1667, 0.1665, 0.1664, 0.1657, 0.1658, 0.1656, 0.1655]

# Plotting the graphs with NeuMF included
plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(epochs, gmf_hr_64, label='GMF')
plt.plot(epochs, mlp_hr_64, label='MLP')
plt.plot(epochs, neumf_hr_64, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('HR', fontsize=14)
plt.title('HR Comparison [Factor 64]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.4500, 0.7200)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))
# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, gmf_ndcg_64, label='GMF')
plt.plot(epochs, mlp_ndcg_64, label='MLP')
plt.plot(epochs, neumf_ndcg_64, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG Comparison [Factor 64]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.260, 0.450)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, gmf_loss_64, label='GMF')
plt.plot(epochs, mlp_loss_64, label='MLP')
plt.plot(epochs, neumf_loss_64, label='NeuMF')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Comparison [Factor 64]', fontsize=16)
plt.legend(fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylim(0.160, 0.370)
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.4f'))


plt.tight_layout()
plt.show()

# %%
# Defining factors and the corresponding metrics for each model
factors = [8, 16, 32, 64]


# GMF metrics
hr_gmf = [0.6397, 0.6962, 0.7129, 0.6997]
ndcg_gmf = [0.3685, 0.4125, 0.4323, 0.4189]
loss_gmf =[0.2666,0.2383,0.2123,0.2255]

# MLP metrics
hr_mlp = [0.6510, 0.6853, 0.6874, 0.707]
ndcg_mlp = [0.3762, 0.4031, 0.4167, 0.432]
loss_mlp =[0.2638,0.2402,0.2236,0.2656]
# # NeuMF w/o Pretrain metrics
# hr_neumf_nopre = [0.6874, 0.6902, 0.6894, 0.6899]
# ndcg_neumf_nopre = [0.4056, 0.4103, 0.4121, 0.4171]
# loss_neumf_nopre = [0.2423,0.2312,0.2286,0.1786]
# NeuMF Pretrain metrics
hr_neumf_pre = [0.684, 0.707, 0.726, 0.730]
ndcg_neumf_pre = [0.403, 0.426, 0.445, 0.447]
loss_neumf_pre=[0.2408,0.2252,0.2109,0.2182]



plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(factors, hr_gmf, marker='o', label='GMF')
plt.plot(factors, hr_mlp, marker='o', label='MLP')
# plt.plot(factors, hr_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, hr_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=14)  # กำหนดค่าแกน x ให้เป็น 8, 16, 32, 64
plt.yticks(fontsize=14)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('HR', fontsize=16)
plt.title('HR vs Factors', fontsize=18)

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(factors, ndcg_gmf, marker='o', label='GMF')
plt.plot(factors, ndcg_mlp, marker='o', label='MLP')
# plt.plot(factors, ndcg_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, ndcg_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('NDCG', fontsize=16)
plt.title('NDCG vs Factors', fontsize=18)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=4, fontsize=14)

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(factors, loss_gmf, marker='o', label='GMF')
plt.plot(factors, loss_mlp, marker='o', label='MLP')
# plt.plot(factors, loss_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, loss_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=18)  # กำหนดค่าแกน x ให้เป็น 8, 16, 32, 64
plt.yticks(fontsize=18)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss vs Factors', fontsize=18)

# Adjusting the layout to ensure all elements fit
plt.tight_layout()
plt.show()

# %%
gmf_hr_8 = [0.4856, 0.5685, 0.5887, 0.5997, 0.6111, 0.6225, 0.6233, 0.6199, 0.6248, 0.6252,0.6285, 0.6288, 0.6328, 0.6311, 0.6334, 0.6344, 0.6316, 0.6328, 0.6353, 0.6368,0.6366, 0.6363, 0.6376, 0.6373, 0.6387, 0.6344, 0.6363, 0.6368, 0.6364, 0.6397,0.6384, 0.6329, 0.6361, 0.6376, 0.6349, 0.6353, 0.6361, 0.6364, 0.6334, 0.6346,0.6396, 0.6369, 0.6328, 0.6334, 0.6373, 0.6374, 0.6384, 0.6368, 0.6373, 0.6358]

loss_gmf_64 = [0.3252, 0.2676, 0.2516, 0.2414, 0.2331, 0.2255, 0.2180, 0.2115, 0.2063, 0.2024,  0.1989, 0.1965, 0.1941, 0.1923, 0.1904, 0.1893, 0.1882, 0.1871, 0.1855, 0.1850, 0.1841, 0.1833, 0.1825, 0.1819, 0.1812, 0.1807, 0.1802, 0.1797, 0.1790, 0.1789,0.1784, 0.1780, 0.1774, 0.1772, 0.1769, 0.1766, 0.1759, 0.1757, 0.1753, 0.1751, 0.1747, 0.1751, 0.1747, 0.1742, 0.1739, 0.1738, 0.1736, 0.1734, 0.1731, 0.1729]


hr_gmf_64_tune = [0.6202, 0.6568, 0.6760, 0.6829, 0.6848, 0.6947, 0.6992, 0.6983, 0.6987,  0.6962, 0.6960, 0.6990, 0.7041, 0.7038, 0.6975, 0.7040, 0.7036, 0.6977, 0.6955, 0.6935, 0.6974, 0.6974, 0.6921, 0.6962, 0.6914, 0.6975, 0.7002, 0.6995, 0.6977,  0.7088, 0.7002, 0.6972, 0.6969, 0.6998, 0.6955, 0.6921, 0.6955, 0.7026, 0.6965, 0.6998, 0.6930, 0.7063, 0.6924, 0.6939, 0.6921, 0.6935, 0.6873, 0.6950, 0.6975,0.6972]

ndcg_gmf_64_tune = [0.3560, 0.3854, 0.4004, 0.4077, 0.4127, 0.4229, 0.4263, 0.4281, 0.4290,  0.4294, 0.4304, 0.4309, 0.4327, 0.4329, 0.4317, 0.4348, 0.4346, 0.4321, 0.4279,0.4325, 0.4299, 0.4304, 0.4294, 0.4288, 0.4263, 0.4316, 0.4327, 0.4331, 0.4315,0.4407, 0.4318, 0.4314, 0.4247, 0.4289, 0.4312, 0.4304, 0.4298, 0.4384, 0.4312,0.4350, 0.4274, 0.4332, 0.4306, 0.4308, 0.4295, 0.4324, 0.4260, 0.4323, 0.4336,0.4293]

loss_gmf_64_tune = [0.2273, 0.1942, 0.1843, 0.1760, 0.1690, 0.1639, 0.1602, 0.1574, 0.1553, 0.1535,0.1525, 0.1515, 0.1509, 0.1503, 0.1498, 0.1496, 0.1492, 0.1490, 0.1487, 0.1490,0.1487, 0.1489, 0.1489, 0.1488, 0.1490, 0.1493, 0.1493, 0.1496, 0.1496, 0.1501,0.1502, 0.1504, 0.1508, 0.1508, 0.1510, 0.1515, 0.1515, 0.1518, 0.1521, 0.1526,0.1529, 0.1528, 0.1535, 0.1537, 0.1539, 0.1543, 0.1545, 0.1548, 0.1554, 0.1556]
# Replotting with all datasets defined
plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(epochs, gmf_hr_8, label='GMF-8')
plt.plot(epochs, gmf_hr_16, label='GMF-16')
plt.plot(epochs, hr_gmf_32, label='GMF-32')
plt.plot(epochs, hr_gmf_64, label='GMF-64')
plt.plot(epochs, hr_gmf_64_tune, label='GMF-64-tune')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('HR', fontsize=14)
plt.title('HR Comparison', fontsize=18)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(epochs, gmf_ndcg_8, label='GMF-8')
plt.plot(epochs, gmf_ndcg_16, label='GMF-16')
plt.plot(epochs, ndcg_gmf_32, label='GMF-32')
plt.plot(epochs, ndcg_gmf_64, label='GMF-64')
plt.plot(epochs, ndcg_gmf_64_tune, label='GMF-64-tune')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG Comparison', fontsize=18)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(epochs, gmf_loss_8, label='GMF-8')
plt.plot(epochs, gmf_loss_16, label='GMF-16')
plt.plot(epochs, loss_gmf_32, label='GMF-32')
plt.plot(epochs, loss_gmf_64, label='GMF-64')
plt.plot(epochs, loss_gmf_64_tune, label='GMF-64-tune')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.title('Loss Comparison', fontsize=18)
plt.legend(fontsize=12)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Defining factors and the corresponding metrics for each model
factors = [8, 16, 32, 64]


# GMF metrics
hr_gmf = [0.6397, 0.6962, 0.7129, 0.6997]
ndcg_gmf = [0.3685, 0.4125, 0.4323, 0.4189]
loss_gmf =[0.2666,0.2383,0.2123,0.2255]

# MLP metrics
hr_mlp = [0.6510, 0.6853, 0.6874, 0.7035]
ndcg_mlp = [0.3762, 0.4031, 0.4167, 0.4261]
loss_mlp =[0.2638,0.2402,0.2236,0.2280]
# # NeuMF w/o Pretrain metrics
# hr_neumf_nopre = [0.6874, 0.6902, 0.6894, 0.6899]
# ndcg_neumf_nopre = [0.4056, 0.4103, 0.4121, 0.4171]
# loss_neumf_nopre = [0.2423,0.2312,0.2286,0.1786]
# NeuMF Pretrain metrics
hr_neumf_pre = [0.684, 0.707, 0.726, 0.730]
ndcg_neumf_pre = [0.403, 0.426, 0.445, 0.447]
loss_neumf_pre=[0.2408,0.2252,0.2109,0.2182]



plt.figure(figsize=(20, 6))

# HR Plot
plt.subplot(1, 3, 1)
plt.plot(factors, hr_gmf, marker='o', label='GMF')
plt.plot(factors, hr_mlp, marker='o', label='MLP')
# plt.plot(factors, hr_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, hr_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=14)  # กำหนดค่าแกน x ให้เป็น 8, 16, 32, 64
plt.yticks(fontsize=14)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('HR', fontsize=16)
plt.title('HR vs Factors', fontsize=18)

# NDCG Plot
plt.subplot(1, 3, 2)
plt.plot(factors, ndcg_gmf, marker='o', label='GMF')
plt.plot(factors, ndcg_mlp, marker='o', label='MLP')
# plt.plot(factors, ndcg_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, ndcg_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('NDCG', fontsize=16)
plt.title('NDCG vs Factors', fontsize=18)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.2), ncol=4, fontsize=14)

# Loss Plot
plt.subplot(1, 3, 3)
plt.plot(factors, loss_gmf, marker='o', label='GMF')
plt.plot(factors, loss_mlp, marker='o', label='MLP')
# plt.plot(factors, loss_neumf_nopre, marker='o', label='NeuMF w/o Pretrain')
plt.plot(factors, loss_neumf_pre, marker='o', label='NeuMF Pretrain')
plt.xticks(factors, fontsize=18)  # กำหนดค่าแกน x ให้เป็น 8, 16, 32, 64
plt.yticks(fontsize=18)
plt.xlabel('Factors', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss vs Factors', fontsize=18)

# Adjusting the layout to ensure all elements fit
plt.tight_layout()
plt.show()
